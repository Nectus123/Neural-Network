# %% [markdown]
# <a href="https://colab.research.google.com/github/Nectus123/Neural-Network/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import RMSprop, Adam
from keras.utils import to_categorical
import matplotlib.pyplot as plt
np.random.seed(1671) # Для воспроизводимости результатов

# %%
# Сеть и ее обучение
NB_EPOCH = 20
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10 # количество результатов = числу цифр
# OPTIMIZER = SGD() # СГС-оптимизатор
N_HIDDEN = 128
VALIDATION_SPLIT = 0.2 # какая часть обучающего набора зарезервирована для контроля
DROPOUT = 0.3

# %%
# данные: случайно перетасованы и разбиты на обучающий и тестовый набор
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
# X_train содержит 60000 изображений размера 28х28 --> преобразуем в массив 60000x784
RESHAPED = 784
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
# Нормируем
X_train /= 255
X_test /= 255

# %%
print(X_train.shape, 'train samples')
print(X_test.shape, 'test samples')
# Out:
# (60000, 784) train samples
# (10000, 784) test samples

# %%
# X_train[0]

# %%
# Преобразуем векторы классов в бинарные матрицы классов
Y_train = to_categorical(y_train, NB_CLASSES)
Y_test = to_categorical(y_test, NB_CLASSES)

# %%
#10 выходов, на последнем этапе softmax
model = Sequential()
model.add(Dense(N_HIDDEN, input_shape=(RESHAPED,)))
model.add(Activation('relu'))
model.add(Dropout(DROPOUT))
model.add(Dense(N_HIDDEN))
model.add(Activation('relu'))
model.add(Dropout(DROPOUT))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               100480
#
#  activation (Activation)     (None, 128)               0
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  activation_1 (Activation)   (None, 128)               0
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 10)                1290
#
#  activation_2 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 118282 (462.04 KB)
# Trainable params: 118282 (462.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])

# %%
history = model.fit(X_train, Y_train,
                    batch_size=BATCH_SIZE, epochs = NB_EPOCH,
                    verbose = VERBOSE, validation_split = VALIDATION_SPLIT)
# Out:
# Epoch 1/20
# 375/375 [==============================] - 4s 8ms/step - loss: 0.5077 - accuracy: 0.8452 - val_loss: 0.1823 - val_accuracy: 0.9477
# Epoch 2/20
# 375/375 [==============================] - 3s 7ms/step - loss: 0.2292 - accuracy: 0.9320 - val_loss: 0.1367 - val_accuracy: 0.9592
# Epoch 3/20
# 375/375 [==============================] - 4s 11ms/step - loss: 0.1752 - accuracy: 0.9479 - val_loss: 0.1145 - val_accuracy: 0.9669
# Epoch 4/20
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1444 - accuracy: 0.9558 - val_loss: 0.1060 - val_accuracy: 0.9688
# Epoch 5/20
# 375/375 [==============================] - 2s 7ms/step - loss: 0.1285 - accuracy: 0.9608 - val_loss: 0.0995 - val_accuracy: 0.9695
# Epoch 6/20
# 375/375 [==============================] - 5s 13ms/step - loss: 0.1146 - accuracy: 0.9652 - val_loss: 0.0937 - val_accuracy: 0.9727
# Epoch 7/20
# 375/375 [==============================] - 6s 16ms/step - loss: 0.1016 - accuracy: 0.9694 - val_loss: 0.0959 - val_accuracy: 0.9723
# Epoch 8/20
# 375/375 [==============================] - 4s 12ms/step - loss: 0.0925 - accuracy: 0.9706 - val_loss: 0.0885 - val_accuracy: 0.9745
# Epoch 9/20
# 375/375 [==============================] - 3s 9ms/step - loss: 0.0883 - accuracy: 0.9728 - val_loss: 0.0828 - val_accuracy: 0.9749
# Epoch 10/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.0819 - accuracy: 0.9736 - val_loss: 0.0822 - val_accuracy: 0.9757
# Epoch 11/20
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0773 - accuracy: 0.9755 - val_loss: 0.0887 - val_accuracy: 0.9758
# Epoch 12/20
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0757 - accuracy: 0.9766 - val_loss: 0.0877 - val_accuracy: 0.9758
# Epoch 13/20
# 375/375 [==============================] - 2s 7ms/step - loss: 0.0696 - accuracy: 0.9778 - val_loss: 0.0888 - val_accuracy: 0.9755
# Epoch 14/20
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0666 - accuracy: 0.9787 - val_loss: 0.0867 - val_accuracy: 0.9768
# Epoch 15/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.0616 - accuracy: 0.9792 - val_loss: 0.0934 - val_accuracy: 0.9747
# Epoch 16/20
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0624 - accuracy: 0.9799 - val_loss: 0.0851 - val_accuracy: 0.9771
# Epoch 17/20
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0581 - accuracy: 0.9807 - val_loss: 0.0923 - val_accuracy: 0.9754
# Epoch 18/20
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0570 - accuracy: 0.9815 - val_loss: 0.0835 - val_accuracy: 0.9778
# Epoch 19/20
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0527 - accuracy: 0.9828 - val_loss: 0.0876 - val_accuracy: 0.9767
# Epoch 20/20
# 375/375 [==============================] - 4s 10ms/step - loss: 0.0551 - accuracy: 0.9817 - val_loss: 0.0859 - val_accuracy: 0.9774

# %%
score = model.evaluate(X_test, Y_test, verbose=VERBOSE)
print("Test score: ",score[0])
print('Test accuracy: ',score[1])
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0753 - accuracy: 0.9800
# Test score:  0.07526910305023193
# Test accuracy:  0.9800000190734863

# %%
plt.plot(history.history['loss'], 'r', label='Training loss')
plt.plot(history.history['val_loss'], 'g', label='Validation loss')
plt.title('Training VS Validation loss')
plt.xlabel('No. of Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'], 'r', label='Training accuracy')
plt.plot(history.history['val_accuracy'], 'g', label='Validation accuracy')
plt.title('Training Vs Validation Accuracy')
plt.xlabel('No. of Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
